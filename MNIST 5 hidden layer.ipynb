# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.utils.np_utils import to_categorical
import glob

seed=7
np.random.seed(seed)

X_train = np.load("C:\\Users\\DELL1\\Downloads\\train_images.npy", allow_pickle=True).astype('float32')
X_test = np.load("C:\\Users\\DELL1\\Downloads\\test_images.npy", allow_pickle=True).astype('float32')
y_train = np.load("C:\\Users\\DELL1\\Downloads\\train_labels.npy", allow_pickle=True)
y_test = np.load("C:\\Users\\DELL1\\Downloads\\test_labels.npy", allow_pickle=True)

X_train=X_train/255
X_test=X_test/255
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

n_classes=y_test.shape[1]
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000, 10)
# (10000, 784)
# (10000, 10)

# %%
def base_model():
    model=Sequential()
    model.add(Dense(200,input_dim=784,activation='relu'))
    model.add(Dense(100,activation='relu'))
    model.add(Dense(60,activation='relu'))
    model.add(Dense(30,activation='relu'))
    model.add(Dense(10,activation='softmax'))
    model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
    return model

model=base_model()
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=10,batch_size=200,verbose=2)

scores=model.evaluate(X_test,y_test,verbose=0)
print("Baseline Error: %.2f%%" %(100-scores[1]*100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
#  - 5s - loss: 0.3754 - accuracy: 0.8925 - val_loss: 0.1612 - val_accuracy: 0.9521
# Epoch 2/10
#  - 3s - loss: 0.1309 - accuracy: 0.9610 - val_loss: 0.1077 - val_accuracy: 0.9669
# Epoch 3/10
#  - 3s - loss: 0.0895 - accuracy: 0.9723 - val_loss: 0.0875 - val_accuracy: 0.9737
# Epoch 4/10
#  - 3s - loss: 0.0646 - accuracy: 0.9796 - val_loss: 0.0829 - val_accuracy: 0.9750
# Epoch 5/10
#  - 3s - loss: 0.0486 - accuracy: 0.9851 - val_loss: 0.0855 - val_accuracy: 0.9740
# Epoch 6/10
#  - 3s - loss: 0.0398 - accuracy: 0.9880 - val_loss: 0.0788 - val_accuracy: 0.9774
# Epoch 7/10
#  - 3s - loss: 0.0326 - accuracy: 0.9898 - val_loss: 0.0983 - val_accuracy: 0.9733
# Epoch 8/10
#  - 3s - loss: 0.0260 - accuracy: 0.9912 - val_loss: 0.0820 - val_accuracy: 0.9781
# Epoch 9/10
#  - 3s - loss: 0.0225 - accuracy: 0.9929 - val_loss: 0.0900 - val_accuracy: 0.9750
# Epoch 10/10
# ...

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=1000,batch_size=16,verbose=2)

scores=model.evaluate(X_test,y_test,verbose=0)
print("Baseline Error: %.2f%%" %(100-scores[1]*100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1000
#  - 16s - loss: 0.1022 - accuracy: 0.9693 - val_loss: 0.0999 - val_accuracy: 0.9710
# Epoch 2/1000
#  - 18s - loss: 0.0642 - accuracy: 0.9798 - val_loss: 0.0935 - val_accuracy: 0.9746
# Epoch 3/1000
#  - 17s - loss: 0.0534 - accuracy: 0.9834 - val_loss: 0.0850 - val_accuracy: 0.9766
# Epoch 4/1000
#  - 17s - loss: 0.0457 - accuracy: 0.9858 - val_loss: 0.0846 - val_accuracy: 0.9786
# Epoch 5/1000
#  - 17s - loss: 0.0388 - accuracy: 0.9875 - val_loss: 0.0986 - val_accuracy: 0.9764
# Epoch 6/1000
#  - 17s - loss: 0.0345 - accuracy: 0.9896 - val_loss: 0.0900 - val_accuracy: 0.9786
# Epoch 7/1000
#  - 19s - loss: 0.0302 - accuracy: 0.9907 - val_loss: 0.0853 - val_accuracy: 0.9805
# Epoch 8/1000
#  - 18s - loss: 0.0258 - accuracy: 0.9925 - val_loss: 0.0979 - val_accuracy: 0.9784
# Epoch 9/1000
#  - 17s - loss: 0.0261 - accuracy: 0.9922 - val_loss: 0.1223 - val_accuracy: 0.9786
# Epoch 10/1000
# ...
